# %%
import numpy as np
import os
from pathlib import Path

x_values = []
y_values = []
reputation_gains = []
top_100 = []
top_1000 = []
top_2000 = []
top_5000 = []

with open('sybil_experiment_out_flat.txt', "r") as of:
    lines = of.readlines()
    i = 0
for line in lines:
    if i == 0:
        words = line.split()
        beta_decay = float(words[2])
        exploration = float(words[4])
        reputation_gain = float(words[-1])
        x_values.append(beta_decay)
        y_values.append(exploration)
        reputation_gains.append(reputation_gain)
        i = i + 1
    elif i == 1:
        top_100.append(int(line.split()[-1]))
        i = i + 1
    elif i == 2:
        top_1000.append(int(line.split()[-1]))
        i = i + 1
    elif i == 3:
        top_2000.append(int(line.split()[-1]))
        i = i + 1
    elif i == 4:
        top_5000.append(int(line.split()[-1]))
        i = 0

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(x_values, y_values, reputation_gains, cmap='viridis')

# set the labels for the x, y, and z axes
ax.set_xlabel('Beta Decay')
ax.set_ylabel('Exploration Probability')
ax.set_zlabel('Reputation Gain')

# show the plot
plt.show()

# %%
import statsmodels.api as sm
model = sm.OLS(reputation_gains, sm.add_constant(x_values))
results = model.fit()
print("Beta Decay Regression:")
print(results.summary())
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting statsmodels
#   Downloading statsmodels-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 10.9 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /usr/lib/python3/dist-packages (from statsmodels) (1.8.0)
# Requirement already satisfied: numpy>=1.18 in /usr/lib/python3/dist-packages (from statsmodels) (1.21.5)
# Collecting pandas>=1.0
#   Downloading pandas-2.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 11.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: packaging>=21.3 in /usr/lib/python3/dist-packages (from statsmodels) (21.3)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 KB 9.6 MB/s eta 0:00:00
# Collecting python-dateutil>=2.8.2
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.0->statsmodels) (2022.1)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 KB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: tzdata, python-dateutil, patsy, pandas, statsmodels
# Successfully installed pandas-2.0.1 patsy-0.5.3 python-dateutil-2.8.2 statsmodels-0.14.0 tzdata-2023.3
# Beta Decay Regression:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.319
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     52.08
# Date:                Sun, 14 May 2023   Prob (F-statistic):           7.01e-11
# Time:                        02:33:25   Log-Likelihood:                -457.61
# No. Observations:                 113   AIC:                             919.2
# Df Residuals:                     111   BIC:                             924.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         25.8237      2.447     10.552      0.000      20.974      30.673
# x1           -32.0327      4.439     -7.216      0.000     -40.828     -23.237
# ==============================================================================
# Omnibus:                      141.852   Durbin-Watson:                   0.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4497.124
# Skew:                           4.374   Prob(JB):                         0.00
# Kurtosis:                      32.641   Cond. No.                         4.15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm
model = sm.OLS(top_2000, sm.add_constant(y_values))
results = model.fit()
print("Exploration Probability Regression:")
print(results.summary())
# Out:
# Exploration Probability Regression:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     3.595
# Date:                Sun, 14 May 2023   Prob (F-statistic):             0.0605
# Time:                        02:39:32   Log-Likelihood:                -1899.7
# No. Observations:                 113   AIC:                             3803.
# Df Residuals:                     111   BIC:                             3809.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.231e+05   8.42e+05      0.859      0.392   -9.45e+05    2.39e+06
# x1          2.733e+06   1.44e+06      1.896      0.061   -1.23e+05    5.59e+06
# ==============================================================================
# Omnibus:                      153.134   Durbin-Watson:                   1.165
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5233.258
# Skew:                           4.967   Prob(JB):                         0.00
# Kurtosis:                      34.825   Cond. No.                         3.95
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(x_values, y_values, top_100, cmap='viridis')

# set the labels for the x, y, and z axes
ax.set_xlabel('Beta Decay')
ax.set_ylabel('Exploration Probability')
ax.set_zlabel('Sybils in Top 100')

# show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(x_values, y_values, top_1000, cmap='viridis')

# set the labels for the x, y, and z axes
ax.set_xlabel('Beta Decay')
ax.set_ylabel('Exploration Probability')
ax.set_zlabel('Sybils in Top 1000')

# show the plot
plt.show()

# %%
x_values_filtered = [x for x, z in zip(x_values, top_1000) if z < 50000]
y_values_filtered = [y for y, z in zip(y_values, top_1000) if z < 50000]
z_values_filtered = [z for z in top_1000 if z < 50000]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(x_values_filtered, y_values_filtered, z_values_filtered, cmap='viridis')

# set the labels for the x, y, and z axes
ax.set_xlabel('Beta Decay')
ax.set_ylabel('Exploration Probability')
ax.set_zlabel('Sybils in Top 1000')

# show the plot
plt.show()

# %%
import statsmodels.api as sm
